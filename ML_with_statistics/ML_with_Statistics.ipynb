# %%
import numpy as np
import pandas as pd
import warnings as w
w.filterwarnings("ignore")

# %% [markdown]
# Read the dataset

# %%
df = pd.read_csv(r"C:\Users\pjbahaduri7\Downloads\Laliga.csv")
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
df.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Pos                 61
# Team                61
# Seasons             33
# Points              61
# GamesPlayed         53
# GamesWon            59
# GamesDrawn          57
# GamesLost           56
# GoalsFor            60
# GoalsAgainst        61
# Champion             8
# Runner-up           10
# Third                9
# Fourth               9
# Fifth                9
# Sixth                9
# T                   21
# Debut               45
# Since/LastApp       37
# BestPosition        18
# Goal_Differences    54
# WinningPercent      54
# dtype: int64

# %% [markdown]
# Replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
df=df.replace({'-': 0})
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# Print all the teams which have started playing between 1930-1980.

# %%
teams = df[["Team", "Debut"]]
teams["Debut"] = teams["Debut"].str.slice(0,4).astype(int)
teams = teams[teams['Debut'].between(1930, 1980)]
teams
# Out:
#                    Team  Debut
# 3              Valencia   1931
# 5               Sevilla   1934
# 8              Zaragoza   1939
# 9            Real Betis   1932
# 10  Deportivo La Coruna   1941
# 11           Celta Vigo   1939
# 12           Valladolid   1948
# 14       Sporting Gijon   1944
# 15              Osasuna   1935
# 16               Malaga   1949
# 17               Oviedo   1933
# 18             Mallorca   1960
# 19           Las Palmas   1951
# 21              Granada   1941
# 22       Rayo Vallecano   1977
# 23                Elche   1959
# 25             Hercules   1935
# 26             Tenerife   1961
# 27               Murcia   1940
# 28               Alaves   1930
# 29              Levante   1963
# 30            Salamanca   1974
# 31             Sabadell   1943
# 32                Cadiz   1977
# 34            Castellon   1941
# 37              Cordoba   1962
# 39           Recreativo   1978
# 40            Burgos CF   1971
# 41           Pontevedra   1963
# ...

# %% [markdown]
# Print the list of teams which came Top 5 in terms of points

# %%
pts = df[["Team", "Points"]]
df["Points"] = df["Points"].astype('int')
pts = pts.nlargest(5, "Points")
for index,row in pts.iterrows():
    print(row["Team"])
# Out:
# Real Madrid
# Barcelona
# Atletico Madrid
# Valencia
# Athletic Bilbao

# %% [markdown]
# Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference.

# %%
def Goals_diff_count(df):
    df["GoalsFor"] = df["GoalsFor"].astype(int)
    df["GoalsAgainst"] = df["GoalsAgainst"].astype(int)
    df["Goal_Differences"] = df.apply(lambda row: row.GoalsFor - row.GoalsAgainst, axis = 1)
#     min_d = np.min()
#     max_d = np.max()
    return df
Goals_diff_count(df)
# Out:
#     Pos              Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86    4385        2762     1647        552
# 1     2         Barcelona       86    4262        2762     1581        573
# 2     3   Atletico Madrid       80    3442        2614     1241        598
# 3     4          Valencia       82    3386        2664     1187        616
# 4     5   Athletic Bilbao       86    3368        2762     1209        633
# ..  ...               ...      ...     ...         ...      ...        ...
# 56   57             Xerez        1      34          38        8         10
# 57   58            Condal        1      22          30        7          8
# 58   59   Atletico Tetuan        1      19          30        7          5
# 59   60  Cultural Leonesa        1      14          30        5          4
# 60   61            Girona        1       0           0        0          0
#
# ...

# %% [markdown]
# Create a new column with name “Winning Percent” and append it to the data set
#
# Percentage of Winning = (GamesWon / GamesPlayed)*100
#
# If there are any numerical error, replace it with 0%
#
# Print the top 5 teams which has the highest Winning percentage

# %%
df["WinningPercent"] = df['GoalsFor'].astype(int) - df['GoalsAgainst'].astype(int)
df
# Out:
#     Pos              Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86    4385        2762     1647        552
# 1     2         Barcelona       86    4262        2762     1581        573
# 2     3   Atletico Madrid       80    3442        2614     1241        598
# 3     4          Valencia       82    3386        2664     1187        616
# 4     5   Athletic Bilbao       86    3368        2762     1209        633
# ..  ...               ...      ...     ...         ...      ...        ...
# 56   57             Xerez        1      34          38        8         10
# 57   58            Condal        1      22          30        7          8
# 58   59   Atletico Tetuan        1      19          30        7          5
# 59   60  Cultural Leonesa        1      14          30        5          4
# 60   61            Girona        1       0           0        0          0
#
# ...

# %% [markdown]
# Group teams based on their “Best position” and print the sum of their points for all positions

# %%
df['Points']=df['Points'].astype(int)
df.groupby('BestPosition', as_index = False)['Points'].sum()
# Out:
#     BestPosition  Points
# 0              1   27933
# 1              2    6904
# 2              3    5221
# 3              4    6563
# 4              5    1884
# 5              6    2113
# 6              7    1186
# 7              8    1134
# 8              9      96
# 9             10     450
# 10            11     445
# 11            12     511
# 12            14      71
# 13            15      14
# 14            16      81
# 15            17     266
# 16            19      81
# 17            20      34
