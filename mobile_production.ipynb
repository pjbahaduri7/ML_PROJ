# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings as w
w.filterwarnings("ignore")
from sklearn.metrics import r2_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# DATASET LINK : https://www.kaggle.com/iabhishekofficial/mobile-price-classification

# %%
df = pd.read_csv(r"C:\Users\pjbahaduri7\Downloads\train (1).csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
# Train dataset null values - data cleaning
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
print("Duplicate values: ",df.duplicated(keep="first").any())
# Out:
# Duplicate values:  False

# %%
df.groupby("price_range").mean()
# Out:
#              battery_power   blue  clock_speed  dual_sim     fc  four_g  \
# price_range
# 0                 1116.902  0.486       1.5502     0.500  4.084   0.518
# 1                 1228.868  0.490       1.4886     0.510  4.340   0.524
# 2                 1228.320  0.486       1.5298     0.498  4.498   0.494
# 3                 1379.984  0.518       1.5204     0.530  4.316   0.550
#
#              int_memory   m_dep  mobile_wt  n_cores      pc  px_height  \
# price_range
# 0                31.174  0.4902    140.552    4.600   9.574    536.408
# 1                32.116  0.5240    140.510    4.298   9.924    666.892
# 2                30.920  0.4908    143.614    4.682  10.018    632.284
# 3                33.976  0.5020    136.320    4.502  10.150    744.848
#
#              px_width       ram    sc_h   sc_w  talk_time  three_g  \
# price_range
# 0            1150.270   785.314  12.324  5.682     10.612    0.746
# 1            1251.908  1679.490  12.212  5.544     11.362    0.756
# ...

# %%
a = df[["three_g", "n_cores"]][df["three_g"] == 1][df["n_cores"] == 4].count()
a
# Out:
# three_g    215
# n_cores    215
# dtype: int64

# %%
b = df[["four_g", "n_cores"]][df["four_g"] == 1][df["n_cores"] == 4].count()
b
# Out:
# four_g     146
# n_cores    146
# dtype: int64

# %%
c = pd.concat([a,b], axis=0, sort=True).drop("n_cores")
c
# Out:
# three_g    215
# four_g     146
# dtype: int64

# %%
labels = ["Touchscreen","Not Touchscreen"]
values = df["touch_screen"].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
labels = ["Dual Sim","Not Dual Sim"]
values = df["dual_sim"].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
sns.lineplot(x="int_memory", y="ram", hue="price_range", data=df_tr)

# %%
# Feature Selection using Pearson correlation
cor = df.corr()
cor
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(cor, annot=True, cmap=plt.cm.GnBu)
plt.show()

# %%
# manipulate the predictor/dependent variable to find the best features of the dataset
target = abs(cor["price_range"])
final = target[target >= 0.10]
final
# Out:
# battery_power    0.200723
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# price_range      1.000000
# Name: price_range, dtype: float64

# %%
best_features = df[["battery_power","px_height","px_width","ram","price_range"]]
best_features
# Out:
#       battery_power  px_height  px_width   ram  price_range
# 0               842         20       756  2549            1
# 1              1021        905      1988  2631            2
# 2               563       1263      1716  2603            2
# 3               615       1216      1786  2769            2
# 4              1821       1208      1212  1411            1
# ...             ...        ...       ...   ...          ...
# 1995            794       1222      1890   668            0
# 1996           1965        915      1965  2032            2
# 1997           1911        868      1632  3057            3
# 1998           1512        336       670   869            0
# 1999            510        483       754  3919            3
#
# [2000 rows x 5 columns]

# %%
# dividing the dataset into to train and test samples
x = best_features.drop(["price_range"], axis=1)
y = best_features["price_range"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=50)

# %%
# shapes of the train and test splits
print("x_train shape: ",x_train.shape)
print("x_test shape: ",x_test.shape)
print("y_train shape: ",y_train.shape)
print("y_test shape: ",y_test.shape)
# Out:
# x_train shape:  (1400, 4)
# x_test shape:  (600, 4)
# y_train shape:  (1400,)
# y_test shape:  (600,)

# %%
# Using Linear Regression
li = LinearRegression()
li.fit(x_train,y_train)
y_pred = li.predict(x_test)
print("The accuracy of the model is: {:.0%}".format(r2_score(y_test,y_pred)))
# Out:
# The accuracy of the model is: 92%

# %%
# using Logistic Regression
li = LogisticRegression()
li.fit(x_train,y_train)
y_pred = li.predict(x_test)
print("The accuracy of the model : {:.0%}".format(m.accuracy_score(y_test,y_pred)))
# Out:
# The accuracy of the model : 97%

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)
print("Accuracy: {:.0%}".format(m.accuracy_score(y_test,y_pred)))
print("Confusion Matrix",confusion_matrix(y_test,y_pred))
print("Precision Score: {:.0%}".format(precision_score(y_test,y_pred,pos_label="positive",average="micro")))
print("Recall Score: {:.0%}".format(recall_score(y_test,y_pred,pos_label="positive",average="micro")))
# Out:
# Accuracy: 88%
# Confusion Matrix [[140  15   0   0]
#  [  9 126  16   0]
#  [  0  10 130   9]
#  [  0   0  16 129]]
# Precision Score: 88%
# Recall Score: 88%
