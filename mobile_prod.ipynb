# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
# from sklearn.metrics import mean_squared_error, r2_score

# %%
df_tr = pd.read_csv(r"C:\Users\pjbahaduri7\Downloads\train (1).csv")
df_te = pd.read_csv(r"C:\Users\pjbahaduri7\Downloads\test.csv")
df_tr
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df_te
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
# there is no need of data cleaning as we do not have null values in both the train and test dataset
df_tr.isnull().sum()
df_te.isnull().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
df_tr.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df_tr.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df_tr.groupby("price_range").mean()
# Out:
#              battery_power   blue  clock_speed  dual_sim     fc  four_g  \
# price_range
# 0                 1116.902  0.486       1.5502     0.500  4.084   0.518
# 1                 1228.868  0.490       1.4886     0.510  4.340   0.524
# 2                 1228.320  0.486       1.5298     0.498  4.498   0.494
# 3                 1379.984  0.518       1.5204     0.530  4.316   0.550
#
#              int_memory   m_dep  mobile_wt  n_cores      pc  px_height  \
# price_range
# 0                31.174  0.4902    140.552    4.600   9.574    536.408
# 1                32.116  0.5240    140.510    4.298   9.924    666.892
# 2                30.920  0.4908    143.614    4.682  10.018    632.284
# 3                33.976  0.5020    136.320    4.502  10.150    744.848
#
#              px_width       ram    sc_h   sc_w  talk_time  three_g  \
# price_range
# 0            1150.270   785.314  12.324  5.682     10.612    0.746
# 1            1251.908  1679.490  12.212  5.544     11.362    0.756
# ...

# %%
a = df_tr[["three_g", "n_cores"]][df_tr["three_g"] == 1][df_tr["n_cores"] == 4].count()
a
# Out:
# C:\Users\pjbahaduri7\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# three_g    215
# n_cores    215
# dtype: int64

# %%
b = df_tr[["four_g", "n_cores"]][df_tr["four_g"] == 1][df_tr["n_cores"] == 4].count()
b
# Out:
# C:\Users\pjbahaduri7\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# four_g     146
# n_cores    146
# dtype: int64

# %%
c = pd.concat([a,b], axis=0, sort=True).drop("n_cores")
c
# Out:
# three_g    215
# four_g     146
# dtype: int64

# %%
sns.scatterplot(x="clock_speed", y="battery_power", hue="price_range", data=df_tr)

# %%
sns.lineplot(x="int_memory", y="ram", hue="price_range", data=df_tr)

# %%
mob_tr_x = df_tr[:-20] 
mob_te_x = df_te[-20:]
mob_tr_y = df_tr[:-20]
mob_te_y = df_te[-20:]
reg = linear_model.LinearRegression()
# training the model using the training sets
reg.fit(mob_tr_x, mob_tr_y)
# make predictions using the testing set
mob_y_pred = reg.predict(mob_te_x)

# %%
# # the coefficients
# print("Coefficient: ", reg.coef_)
# # the mean squared values
# print("The mean squared values: %.2f" %r2_score(mob_te_y, mob_y_pred))

# %%
plt.scatter(mob_te_x, mob_te_y, color="red")
plt.plot(mob_te_x, mob_y_pred, color="blue", linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
